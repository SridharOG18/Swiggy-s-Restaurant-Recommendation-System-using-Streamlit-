# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("D:/Swiggy_Proj/Swiggy_projwork/swiggy.csv")
df.head(50)
# Out:
#         id                                          name    city rating  \
# 0   567335                                AB FOODS POINT  Abohar     --
# 1   531342                             Janta Sweet House  Abohar    4.4
# 2   158203                             theka coffee desi  Abohar    3.8
# 3   187912                                     Singh Hut  Abohar    3.7
# 4   543530                                 GRILL MASTERS  Abohar     --
# 5   158204                                     Sam Uncle  Abohar    3.6
# 6   156588                              shere punjab veg  Abohar    4.0
# 7   244866                     Shri Balaji Vaishno Dhaba  Abohar     --
# 8   156602                      Hinglaj Kachori Bhandhar  Abohar    4.2
# 9   158193                                     yummy hub  Abohar     --
# 10  407249                  CHAWLA SAAB THE JUICE MASTER  Abohar     --
# 11  156590                              Sethi Milk Badam  Abohar    4.2
# ...

# %%
df.drop(columns=["link", "address", "menu"], inplace=True)

# %%
df.drop(columns=["lic_no"], inplace=True)
data
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148437  553122          The Food Delight  Yavatmal     3.0            10
# 148438  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148439  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148440  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148441  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#         cost                     cuisine  name_encoded  city_encoded  \
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#             id                      name      city rating     rating_count  \
# 0       567335            AB FOODS POINT    Abohar     --  Too Few Ratings
# 1       531342         Janta Sweet House    Abohar    4.4      50+ ratings
# 2       158203         theka coffee desi    Abohar    3.8     100+ ratings
# 3       187912                 Singh Hut    Abohar    3.7      20+ ratings
# 4       543530             GRILL MASTERS    Abohar     --  Too Few Ratings
# ...        ...                       ...       ...    ...              ...
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost                     cuisine
# ...

# %%
df['rating'].replace('--', 3.0, inplace=True)  # Replace '--' with 3.0
df['rating'] = df['rating'].astype(float)  # Convert to float

# %%
df['rating_count'].replace("Too Few Ratings", "10", inplace=True)

# %%
df['rating'].replace('--', 3.0, inplace=True)  # Replace '--' with 3.0
df['rating'] = df['rating'].astype(float)  # Convert to float

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4   50+ ratings
# 2       158203         theka coffee desi    Abohar     3.8  100+ ratings
# 3       187912                 Singh Hut    Abohar     3.7   20+ ratings
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#          cost                     cuisine
# 0       ₹ 200            Beverages,Pizzas
# ...

# %%
# Check the data types of all columns in the DataFrame
print(df.dtypes)
# Out:
# id                int64
# name             object
# city             object
# rating          float64
# rating_count     object
# cost             object
# cuisine          object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['rating'] = df['rating'].fillna(3.0)

# %%
# Check for unique values in the 'rating' column
print(df['rating'].unique())
# Out:
# [3.  4.4 3.8 3.7 3.6 4.  4.2 4.7 4.1 3.5 3.1 3.4 3.3 4.8 3.9 2.7 4.3 2.9
#  4.5 2.5 3.2 2.4 4.6 2.8 2.3 5.  2.6 2.2 1.4 1.9 4.9 2.1 1.3 2.  1.8 1.6
#  1.1 1.5 1.  1.2 1.7]

# %%
print(df['rating'].dtype)
# Out:
# float64

# %%
print(df['rating'].isnull().sum())
# Out:
# 0

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4   50+ ratings
# 2       158203         theka coffee desi    Abohar     3.8  100+ ratings
# 3       187912                 Singh Hut    Abohar     3.7   20+ ratings
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#          cost                     cuisine
# 0       ₹ 200            Beverages,Pizzas
# ...

# %%
# Remove "+ ratings" from the 'rating_count' column
df['rating_count'] = df['rating_count'].str.replace("+ ratings", "").str.strip()

# %%
df
# Out:
#             id                      name      city  rating rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0           10
# 1       531342         Janta Sweet House    Abohar     4.4           50
# 2       158203         theka coffee desi    Abohar     3.8          100
# 3       187912                 Singh Hut    Abohar     3.7           20
# 4       543530             GRILL MASTERS    Abohar     3.0           10
# ...        ...                       ...       ...     ...          ...
# 148536  553122          The Food Delight  Yavatmal     3.0           10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0           10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0           10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0           10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0           10
#
#          cost                     cuisine
# 0       ₹ 200            Beverages,Pizzas
# ...

# %%
# Check for unique values in the 'rating' column
print(df['rating_count'].unique())
# Out:
# ['10' '50' '100' '20' '500' '1K' '5K' nan '10K']

# %%
# Replace '1K', '5K', and '10K' with their numeric equivalents, and handle NaN values
df['rating_count'] = df['rating_count'].replace({
    '1K': 1000,
    '5K': 5000,
    '10K': 10000,
    np.nan: 3.0  # Replace NaN with 3.0
})

# Convert the column to numeric for consistency
df['rating_count'] = df['rating_count'].astype(float)

# Verify the changes
print(df['rating_count'].unique())
# Out:
# [1.e+01 5.e+01 1.e+02 2.e+01 5.e+02 1.e+03 5.e+03 3.e+00 1.e+04]

# %%
# Convert the 'rating_count' column to float and ensure standard float formatting
df['rating_count'] = df['rating_count'].astype(float)

# Optionally, format the display settings in pandas to avoid scientific notation
pd.options.display.float_format = '{:.1f}'.format

# Verify the changes
print(df['rating_count'].head())
# Out:
# 0    10.0
# 1    50.0
# 2   100.0
# 3    20.0
# 4    10.0
# Name: rating_count, dtype: float64

# %%
# Convert the 'rating_count' column to integers
df['rating_count'] = df['rating_count'].astype(int)

# Verify the changes
print(df['rating_count'].head())
# Out:
# 0     10
# 1     50
# 2    100
# 3     20
# 4     10
# Name: rating_count, dtype: int32

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#          cost                     cuisine
# 0       ₹ 200            Beverages,Pizzas
# ...

# %%
# Convert the 'rating_count' column to integers
df['rating_count'] = df['rating_count'].astype(int)

# %%
# Check the data types of all columns in the DataFrame
print(df.dtypes)
# Out:
# id                int64
# name             object
# city             object
# rating          float64
# rating_count      int32
# cost             object
# cuisine          object
# dtype: object

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#          cost                     cuisine
# 0       ₹ 200            Beverages,Pizzas
# ...

# %%
df['cost'] = df['cost'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#         cost                     cuisine
# 0      200.0            Beverages,Pizzas
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.fillna({'cost': df['cost'].mean()}, inplace=True)

# %%
df.isnull().sum()
# Out:
# id               0
# name            86
# city             0
# rating           0
# rating_count     0
# cost             0
# cuisine         99
# dtype: int64

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#         cost                     cuisine
# 0      200.0            Beverages,Pizzas
# ...

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#         cost                     cuisine
# 0      200.0            Beverages,Pizzas
# ...

# %%
df.to_csv("D:/Swiggy_Proj/Swiggy_projwork/cleaned_data.csv", index=False)
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148536  553122          The Food Delight  Yavatmal     3.0            10
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148538  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148539  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148540  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#         cost                     cuisine
# 0      200.0            Beverages,Pizzas
# ...

# %%
df_cleaned = df.drop_duplicates()
print("/nShape after removing duplicates:", df_cleaned.shape)
# Out:
# Shape after removing duplicates: (148541, 7)

# %%
df_cleaned = df_cleaned.dropna()

# %%
numeric_columns = df_cleaned.select_dtypes(include=[np.number]).columns
df_cleaned[numeric_columns] = df_cleaned[numeric_columns].fillna(df_cleaned[numeric_columns].mean())

# %%
categorical_columns = df_cleaned.select_dtypes(include=['object']).columns
df_cleaned[categorical_columns] = df_cleaned[categorical_columns].fillna(df_cleaned[categorical_columns].mode().iloc[0])

# %%
df_cleaned.to_csv('cleaned_data.csv', index=False)
print("/nCleaned data saved successfully!")
# Out:
# Cleaned data saved successfully!

# %%
One-Hot Encoding
Clustering (K-Means, Cosine Similarity, or Similar Methods)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pickle

# %%
df = pd.read_csv('cleaned_data.csv')
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148437  553122          The Food Delight  Yavatmal     3.0            10
# 148438  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148439  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148440  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148441  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#         cost                     cuisine
# 0      200.0            Beverages,Pizzas
# ...

# %%
label_encoders = {}

# %%
categorical_columns = ['name', 'city', 'cuisine']
for column in categorical_columns:
    # Create and fit LabelEncoder
    label_encoders[column] = LabelEncoder()
    df[f"{column}_encoded"] = label_encoders[column].fit_transform(df[column])

# %%
df_encoded = df.drop(columns=categorical_columns)

# %%
df
# Out:
#             id                      name      city  rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar     3.0            10
# 1       531342         Janta Sweet House    Abohar     4.4            50
# 2       158203         theka coffee desi    Abohar     3.8           100
# 3       187912                 Singh Hut    Abohar     3.7            20
# 4       543530             GRILL MASTERS    Abohar     3.0            10
# ...        ...                       ...       ...     ...           ...
# 148437  553122          The Food Delight  Yavatmal     3.0            10
# 148438  562647  MAITRI FOODS & BEVERAGES  Yavatmal     3.0            10
# 148439  559435           Cafe Bella Ciao  Yavatmal     3.0            10
# 148440  418989               GRILL ZILLA  Yavatmal     3.0            10
# 148441  447770            Lazeez kitchen  Yavatmal     3.0            10
#
#         cost                     cuisine  name_encoded  city_encoded  \
# ...

# %%
with open('label_encoders.pkl', 'wb') as f:
    pickle.dump(label_encoders, f)

# %%
df_encoded.to_csv("D:/Swiggy_Proj/Swiggy_projwork/encoded_data.csv", index=False)

# %%
print("\nSample of encoded data:")
print(df_encoded.head())
# Out:
# Sample of encoded data:
#        id  rating  rating_count  cost  name_encoded  city_encoded  \
# 0  567335     3.0            10 200.0          1583             1
# 1  531342     4.4            50 200.0         47415             1
# 2  158203     3.8           100 100.0        112634             1
# 3  187912     3.7            20 250.0         90297             1
# 4  543530     3.0            10 250.0         34936             1
#
#    cuisine_encoded
# 0              328
# 1             1983
# 2              289
# 3              796
# 4             1166

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Load the original cleaned data
df = pd.read_csv('cleaned_data.csv')

# Initialize dictionary for storing encoders
label_encoders = {}

# Specify the categorical columns
categorical_columns = ['name', 'city', 'cuisine']

# Encode each column
for column in categorical_columns:
    label_encoders[column] = LabelEncoder()
    df[f"{column}_encoded"] = label_encoders[column].fit_transform(df[column])

# Drop original columns and save
df_encoded = df.drop(columns=categorical_columns)
df_encoded.to_csv('encoded_data.csv', index=False)

# Save the encoders
import pickle
with open('label_encoders.pkl', 'wb') as f:
    pickle.dump(label_encoders, f)

# %%
# Reloading the original cleaned data and encoded dataset
original_df = pd.read_csv('D:/Swiggy_Proj/Swiggy_Stremlit/cleaned_data.csv')
encoded_df = pd.read_csv('D:/Swiggy_Proj/Swiggy_Stremlit/encoded_data.csv')

# Encode the 'city' column
from sklearn.preprocessing import LabelEncoder
city_encoder = LabelEncoder()
encoded_df['city_encoded'] = city_encoder.fit_transform(original_df['city'])

# Save the updated encoded dataset
encoded_df.to_csv('D:/Swiggy_Proj/Swiggy_Stremlit/encoded_data.csv', index=False)

# Optionally save the city encoder
with open('city_encoder.pkl', 'wb') as f:
    pickle.dump(city_encoder, f)

# %%
columns_to_use = ['id', 'name_encoded', 'city_encoded', 'cuisine_encoded', 'rating']

# %%
encoded_df = pd.read_csv('encoded_data.csv')
print("Updated columns in encoded_df:", encoded_df.columns)
# Out:
# Updated columns in encoded_df: Index(['id', 'rating', 'rating_count', 'cost', 'name_encoded', 'city_encoded',
#        'cuisine_encoded'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
import pickle
from collections import defaultdict

# Load the updated encoded dataset
encoded_df = pd.read_csv("D:/Swiggy_Proj/Swiggy_Stremlit/encoded_data.csv")
original_df = pd.read_csv("D:/Swiggy_Proj/Swiggy_Stremlit/cleaned_data.csv")

# Clean and prepare the data for clustering
def clean_and_prepare_data(df):
    df_clean = df.copy()
    columns_to_use = ['id', 'name_encoded', 'city_encoded', 'cuisine_encoded', 'rating']
    df_clean['rating'] = pd.to_numeric(df_clean['rating'].replace('--', np.nan), errors='coerce')
    df_clean = df_clean[columns_to_use]
    df_clean = df_clean.fillna(df_clean.mean())  # Fill missing values with mean
    return df_clean

# Clean and scale the data
encoded_df_clean = clean_and_prepare_data(encoded_df)
scaler = StandardScaler()
scaled_features = scaler.fit_transform(encoded_df_clean)

# Save the scaler
with open('D:/Swiggy_Proj/Swiggy_Stremlit/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# MiniBatch K-Means clustering
def create_cluster_based_recommender(n_clusters=100, batch_size=1000):
    kmeans = MiniBatchKMeans(
        n_clusters=n_clusters,
        batch_size=batch_size,
        random_state=42
    )
    cluster_labels = kmeans.fit_predict(scaled_features)
    
    # Create a mapping of cluster to restaurant indices
    cluster_to_restaurants = defaultdict(list)
    for idx, label in enumerate(cluster_labels):
        cluster_to_restaurants[label].append(idx)
    
    # Save the clustering model and mappings
    with open('D:/Swiggy_Proj/Swiggy_Stremlit/minibatch_kmeans_model.pkl', 'wb') as f:
        pickle.dump((kmeans, cluster_to_restaurants), f)
    
    # Define the recommendation function
    def get_recommendations(restaurant_id, n_recommendations=5):
        try:
            restaurant_features = scaled_features[restaurant_id].reshape(1, -1)
            restaurant_cluster = kmeans.predict(restaurant_features)[0]
            cluster_restaurants = cluster_to_restaurants[restaurant_cluster]
            
            # Exclude the input restaurant
            other_restaurants = [idx for idx in cluster_restaurants if idx != restaurant_id]
            
            # Sort recommendations by rating
            recommendations_df = original_df.iloc[other_restaurants].copy()
            recommendations_df['rating'] = pd.to_numeric(recommendations_df['rating'], errors='coerce')
            recommendations_df = recommendations_df.sort_values('rating', ascending=False)
            
            return recommendations_df.head(n_recommendations)
        except Exception as e:
            print(f"Error in getting recommendations: {str(e)}")
            return pd.DataFrame()
    
    return get_recommendations

# Initialize the recommender system
recommender = create_cluster_based_recommender()

# **Recommendation example**
def get_recommendations(restaurant_id, n_recommendations=5):
    print(f"\nRecommendations for Restaurant ID: {restaurant_id}")
    print("\nOriginal Restaurant Details:")
    print(original_df.iloc[restaurant_id][['name', 'city', 'cuisine', 'rating']])
    
    print("\nCluster-Based Recommendations:")
    cluster_recommendations = recommender(restaurant_id, n_recommendations)
    print(cluster_recommendations[['name', 'city', 'cuisine', 'rating']])

# Test the recommendation system
test_id = 1  # Example restaurant ID
get_recommendations(test_id, n_recommendations=5)
# Out:
# D:\course works\Lib\site-packages\sklearn\cluster\_kmeans.py:1972: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(
# Recommendations for Restaurant ID: 1
#
# Original Restaurant Details:
# name       Janta Sweet House
# city                  Abohar
# cuisine        Sweets,Bakery
# rating                   4.4
# Name: 1, dtype: object
#
# Cluster-Based Recommendations:
#                          name                   city              cuisine  \
# 12958      Fresh crunch pizza  Indiranagar,Bangalore       Pizzas,Burgers
# 28438   Flavours of Champaran                Bikaner  North Indian,Bihari
# 23001       DOSE OF DAVANGERE    Jayanagar,Bangalore         South Indian
# 29194          Copper Chimney                Bikaner  North Indian,Indian
# ...

# %%
ALL DONE
